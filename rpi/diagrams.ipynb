# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

df1 = pd.read_csv('test1_monitoring.txt', sep=', ', engine='python')
df1['CPU-Usage'] = df1['CPU-Usage'].str.rstrip('%').astype('float')
df1['Memory'] = df1['Memory'].str.rstrip('%').astype('float')

df2 = pd.read_csv('test_base_line_monitoring.txt', sep=', ', engine='python')
df2['CPU-Usage Base Line'] = df2['CPU-Usage'].str.rstrip('%').astype('float')
df2['Memory Base Line'] = df2['Memory'].str.rstrip('%').astype('float')

df2 = df2[:-9]

plt.figure(figsize=(10,6))

x_values = np.linspace(0, 600, len(df1))
x_values2 = np.linspace(0, 600, len(df2))

plt.plot(x_values, df1['CPU-Usage'], label='CPU-Usage in %')
plt.plot(x_values, df1['Memory'], label='Memory in %')

plt.plot(x_values2, df2['CPU-Usage Base Line'], label='CPU-Usage Base Line', linestyle='--')
plt.plot(x_values2, df2['Memory Base Line'], label='Memory Base Line', linestyle='--')

plt.title('Single Signings')
plt.xlabel('Seconds')
plt.ylabel('Workload in percentage')

plt.xticks(np.linspace(0, 600, len(df)//(600//10)), rotation=45)  # Passt die Anzahl der Ticks an

plt.yticks([0, 5, 10, 15, 20, 25, 30])

plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

df1 = pd.read_csv('test2_monitoring.txt', sep=', ', engine='python')
df1['CPU-Usage'] = df1['CPU-Usage'].str.rstrip('%').astype('float')
df1['Memory'] = df1['Memory'].str.rstrip('%').astype('float')

df2 = pd.read_csv('test_base_line_monitoring.txt', sep=', ', engine='python')
df2['CPU-Usage Base Line'] = df2['CPU-Usage'].str.rstrip('%').astype('float')
df2['Memory Base Line'] = df2['Memory'].str.rstrip('%').astype('float')

df2 = df2[:-9]

plt.figure(figsize=(10,6))

x_values = np.linspace(0, 600, len(df1))
x_values2 = np.linspace(0, 600, len(df2))

plt.plot(x_values, df1['CPU-Usage'], label='CPU-Usage in %')
plt.plot(x_values, df1['Memory'], label='Memory in %')

plt.plot(x_values2, df2['CPU-Usage Base Line'], label='CPU-Usage Base Line', linestyle='--')
plt.plot(x_values2, df2['Memory Base Line'], label='Memory Base Line', linestyle='--')

plt.title('Full aggregation without all data​')
plt.xlabel('Seconds')
plt.ylabel('Workload in percentage')

plt.xticks(np.linspace(0, 600, len(df)//(600//10)), rotation=45)

plt.yticks([0, 5, 10, 15, 20, 25, 30])

plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

df1 = pd.read_csv('test2_monitoring.txt', sep=', ', engine='python')
df1['CPU-Usage'] = df1['CPU-Usage'].str.rstrip('%').astype('float')
df1['Memory'] = df1['Memory'].str.rstrip('%').astype('float')

df2 = pd.read_csv('test_base_line_monitoring.txt', sep=', ', engine='python')
df2['CPU-Usage Base Line'] = df2['CPU-Usage'].str.rstrip('%').astype('float')
df2['Memory Base Line'] = df2['Memory'].str.rstrip('%').astype('float')

df2 = df2[:-9]

plt.figure(figsize=(10,6))

x_values = np.linspace(0, 600, len(df1))
x_values2 = np.linspace(0, 600, len(df2))

plt.plot(x_values, df1['CPU-Usage'], label='CPU-Usage in %')
plt.plot(x_values, df1['Memory'], label='Memory in %')

plt.plot(x_values2, df2['CPU-Usage Base Line'], label='CPU-Usage Base Line', linestyle='--')
plt.plot(x_values2, df2['Memory Base Line'], label='Memory Base Line', linestyle='--')

plt.title('Full aggregation with all data​')
plt.xlabel('Seconds')
plt.ylabel('Workload in percentage')

plt.xticks(np.linspace(0, 600, len(df)//(600//10)), rotation=45)

plt.yticks([0, 5, 10, 15, 20, 25, 30])

plt.legend()
plt.show()
